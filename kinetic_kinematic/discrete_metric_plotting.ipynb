# %%
#This script plots each discrete kinetic and kinematic variable agains the group for visualization purposes

#import libraries
import os
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#load the .csv file
metric_file = pd.read_csv('/Users/rossbrancati/Desktop/PFP_Project/kinetic_kinematic/discrete_data/discrete_data_master.csv',sep=',')
print(metric_file)
# Out:
#       group  peak_hip_rot_stance  peak_hip_add_stance  \
# 0         0            -0.594988            13.835928
# 1         0             0.179642            14.594582
# 2         0             0.049105            14.553577
# 3         0            -1.134884            13.121063
# 4         0            -0.367813            12.689490
# 5         0            -0.478830            13.352461
# 6         0            -1.049916            13.926865
# 7         0            -1.590565            12.722326
# 8         0            -1.730800            11.142318
# 9         0             0.000151            14.422674
# 10        0            -1.325796            13.449057
# 11        0            -1.915652            13.774892
# 12        0            -0.463966            16.403112
# 13        0             0.032265            16.802827
# 14        0            -0.954759            15.286568
# 15        0            -2.790860            15.292253
# ...

# %%
plt.figure(0)
plt.scatter(metric_file.peak_hip_rot_stance, metric_file.group)
plt.title('Peak Hip Rotation Angle - Stance')

plt.figure(1)
plt.scatter(metric_file.peak_hip_add_stance, metric_file.group)
plt.title('Peak Hip Adduction Angle - Stance')

plt.figure(2)
plt.scatter(metric_file.peak_knee_int_rot_stance, metric_file.group)
plt.title('Peak Knee Internal Rotation Angle - Stance')

plt.figure(3)
plt.scatter(metric_file.peak_knee_flex_stance, metric_file.group)
plt.title('Peak Knee Flexion Angle - Stance')

plt.figure(4)
plt.scatter(metric_file.knee_ext_rot_at_knee_ext_mom, metric_file.group)
plt.title('Peak Knee External Rotation Angle at Peak Knee Extension Moment')

plt.figure(5)
plt.scatter(metric_file.peak_knee_ext_moment_stance, metric_file.group)
plt.title('Peak Knee External Rotation Moment - Stance')

plt.figure(6)
plt.scatter(metric_file.peak_knee_add_mom_LR, metric_file.group)
plt.title('Peak Knee Adduction Moment during Loading Response')

plt.figure(7)
plt.scatter(metric_file.knee_abduction_impulse_stance, metric_file.group)
plt.title('Knee Abduction Impulse - Stance')

plt.figure(8)
plt.scatter(metric_file.peak_knee_ext_rot_mom_LR, metric_file.group)
plt.title('Peak Knee External Rotation Moment during Loading Response')

plt.figure(9)
plt.scatter(metric_file.peak_knee_ext_mom_LR, metric_file.group)
plt.title('Peak Knee Extension Moment during Loading Response')

plt.figure(10)
plt.scatter(metric_file.knee_ext_mom_toe_off, metric_file.group)
plt.title('Knee Extension Moment at Toe Off')

plt.figure(11)
plt.scatter(metric_file.peak_knee_adduction_angle_stance, metric_file.group)
plt.title('Peak Knee Adduction Angle - Stance')

plt.figure(12)
plt.scatter(metric_file.rearfoot_eversion_heel_strike, metric_file.group)
plt.title('Rearfoot Eversion at Heel Strike')

plt.figure(13)
plt.scatter(metric_file.rearfoot_eversion_ROM_ten_percent, metric_file.group)
plt.title('Rearfoot Eversion Range of Motion in First 10% of Gait Cycle')

plt.figure(14)
plt.scatter(metric_file.rearfoot_eversion_ROM_stance, metric_file.group)
plt.title('Rearfoot Eversion Range of Motion - Stance')
# Out:
# Text(0.5, 1.0, 'Rearfoot Eversion Range of Motion - Stance')
